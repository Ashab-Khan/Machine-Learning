# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/play_tennis.csv')

# %%
print(df.shape)
df
# Out:
# (14, 6)
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
# Problem 1

# Outlook=Sunny, Temp=Hot , Humidity=High, Wind=Weak
# Play or NoPlay

# %%
# Solution
# P(YES/ sunny,Hot,High,Weak)=P(sunny/Yes)*P(Hot/Yes)*P(High/Yes)*P(Weak/Yes)
# P(No/ sunny,Hot,High,Weak)=P(sunny/No)*P(Hot/No)*P(High/No)*P(Weak/No)

# Compare and decide using the maximum a postiriori rule

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py=9/14
pn=5/14

# %%
# Outlook

pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
poy=4/9
pry=3/9
psy=2/9

pon=0
prn=2/5
psn=3/5

# %%
# Temp

pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pcy=3/9
phy=2/9
pmy=4/9

pcn=1/5
phn=2/5
pmn=2/5

# %%
# Humidity

pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
phighy=3/9
pnormaly=6/9

phighn=4/5
pnormaln=1/5

# %%
# Wind

pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
pstrongy=3/9
pweary=6/9

pstrongn=3/5
pweakn=2/5

# %%
# Outlook=Sunny, Temp=Hot , Humidity=High, Wind=Weak

pyes=psy*phy*phighy*pstrongy*py
pno=psn*phn*phighn*pweakn*pn

# %%
print(pyes)
print(pno)
# Out:
# 0.0035273368606701934
# 0.02742857142857143

# %%
# So We Will Not Play As The Probability Of PNO is Greater
