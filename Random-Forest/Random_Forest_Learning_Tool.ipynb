# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_features=5,n_informative=5,n_redundant=0,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=['Col1','col2','col3','col4','col5'])
df['Target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        Col1      col2      col3      col4      col5  Target
# 0  0.592265  0.744689 -2.294622  0.169281  2.447161       1
# 1  1.145444  0.423749 -2.627690  0.312505  2.488119       1
# 2  0.493735  0.791957 -2.179130  2.244245  1.730603       1
# 3  6.500569  4.148555 -5.082168  2.107513  5.808251       1
# 4  0.941058 -3.906236  4.999500 -0.176415  0.918407       0

# %%
#function For Row Sampling
def sample_rows(df,percent):
    return df.sample(int(df.shape[0]*percent),replace=True)

# %%
#function For Columns Sampling
import random
def sample_columns(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
    new_df=df[cols]
    new_df['Target']=df['Target']
    return new_df

# %%
# function For Combined Sampling
def combined_sampling(df,row_percent,col_percent):
    new_df=sample_rows(df,row_percent)
    return sample_columns(new_df,col_percent)

# %%
df1=sample_rows(df,0.2)
print(df1)
# Out:
#         Col1      col2      col3      col4      col5  Target
# 40  3.324399  1.804097 -1.304328  0.743381  1.818716       1
# 92  1.214971  0.695585  0.117790 -4.227653  3.481484       0
# 8   0.286051 -1.435591  0.814420 -3.010343  0.887778       0
# 94 -0.256808  0.228138  0.089916  2.320752 -0.923317       1
# 37  0.167044  0.038877 -0.461204 -2.214643  1.227796       0
# 60 -0.465021 -4.262512  4.001472 -2.177242  0.156711       0
# 93  1.580045  2.802927 -0.736446  2.967990  0.443800       1
# 36  1.035723  1.602138 -0.349312 -0.334412  0.784806       1
# 19  2.045086 -0.659546  0.817175 -0.486046  0.910449       0
# 95  0.947038 -0.081592  0.116951 -0.904328  1.335424       0
# 26 -1.039708 -0.896295 -0.184400  1.285740 -0.701681       1
# 43  2.640512  1.499878 -0.062998  2.713307 -0.214523       1
# 54  0.874179 -3.384119  3.520889  0.293803 -0.193152       0
# 32  0.541277  1.515389 -1.110997 -2.436287  2.940522       1
# ...

# %%
df2=sample_rows(df,0.2)
print(df2)
# Out:
#         Col1      col2      col3      col4      col5  Target
# 54  0.874179 -3.384119  3.520889  0.293803 -0.193152       0
# 62  1.977770  1.270426 -3.075948 -1.344544  3.952563       1
# 31  2.498316  1.106839 -2.375458  1.190672  2.393440       1
# 67  0.643621 -2.141086  1.931778  0.833269 -0.253295       0
# 91  1.905997 -1.761968  2.336550  1.083553  0.458238       0
# 89  1.377975 -0.230126 -0.968744 -0.187484 -0.545299       0
# 40  3.324399  1.804097 -1.304328  0.743381  1.818716       1
# 24 -2.020520 -0.319907 -0.176787  1.280282 -0.713842       1
# 69  1.386607 -0.357108  0.684738 -0.848479  1.592706       0
# 9   0.654409 -3.106824  2.349369  1.105271 -1.334445       0
# 41  1.702513 -0.306534  1.221958 -0.803628  2.177669       0
# 24 -2.020520 -0.319907 -0.176787  1.280282 -0.713842       1
# 22  2.008525  1.329655 -1.185684 -1.399986  1.861347       0
# 83  5.305988  4.560680  0.031183  4.297867  0.511353       1
# ...

# %%
df3=sample_rows(df,0.2)
print(df3)
# Out:
#         Col1      col2      col3      col4      col5  Target
# 21  0.789484 -0.836787  0.559968 -1.575563  1.045432       0
# 56 -0.152311 -0.874268 -1.135738 -0.047881  0.503731       1
# 91  1.905997 -1.761968  2.336550  1.083553  0.458238       0
# 37  0.167044  0.038877 -0.461204 -2.214643  1.227796       0
# 70  1.719395  1.668213  1.216651  2.008272 -1.055089       1
# 51 -1.904658 -0.831667 -0.437041 -1.787925  0.561666       1
# 27  3.089730  2.083528 -2.412602  1.952350  2.366773       1
# 78  1.133903  1.356625 -1.384340 -0.202057  1.931980       1
# 11  1.179519  1.281160 -1.300100  2.132412  0.607767       1
# 53  0.665552  0.861422 -1.723058  2.196099  1.330656       1
# 94 -0.256808  0.228138  0.089916  2.320752 -0.923317       1
# 53  0.665552  0.861422 -1.723058  2.196099  1.330656       1
# 56 -0.152311 -0.874268 -1.135738 -0.047881  0.503731       1
# 63 -0.189035 -1.608664  1.348621 -1.958729  0.945233       0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf2=DecisionTreeClassifier()
clf3=DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6666666666666666, 0.875, 'x[2] <= 0.103\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.5, 0.625, 'x[3] <= -1.275\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'x[1] <= 0.777\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.75, 0.75, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[3] <= 1.148\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.4, 0.5, 'x[2] <= -1.245\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.4, 0.875, 'x[1] <= -1.064\ngini = 0.42\nsamples = 20\nvalue = [6, 14]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30000000000000004, 0.75, 'True  '),
#  Text(0.6, 0.625, 'x[3] <= -0.889\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.5, 0.75, '  False'),
#  Text(0.4, 0.375, 'x[4] <= 0.804\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]')]

# %%
clf1.predict(np.array([-0.920114,-1.568334,0.270559,0.654214,0.806036]).reshape(1,5))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-0.920114,-1.568334,0.270559,0.654214,0.806036]).reshape(1,5))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-0.920114,-1.568334,0.270559,0.654214,0.806036]).reshape(1,5))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df4=sample_columns(df,0.8)
print(df4)
# Out:
#         col3      col4      Col1      col2  Target
# 0   0.026367  1.901801 -1.827113 -1.030160       1
# 1   1.837724  1.095708  0.036828 -0.258587       0
# 2   0.718437  2.776339  0.909340  2.582700       0
# 3   0.702546  1.565525  1.312705  0.563634       0
# 4  -2.413939  1.007192 -1.291486 -1.924846       1
# ..       ...       ...       ...       ...     ...
# 95 -0.502235  1.065477 -0.949356 -0.360138       1
# 96 -1.543247 -0.241655  1.380136 -0.416913       1
# 97  0.417937  2.660665  1.264126  2.917280       0
# 98  1.648145  0.799271 -0.977379  1.117682       0
# 99 -1.409011  0.082613 -1.014580 -0.461554       1
#
# [100 rows x 5 columns]
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df5=sample_columns(df,0.8)
print(df5)
# Out:
#         col3      col4      Col1      col5  Target
# 0   0.026367  1.901801 -1.827113  0.216547       1
# 1   1.837724  1.095708  0.036828  1.191991       0
# 2   0.718437  2.776339  0.909340  3.169328       0
# 3   0.702546  1.565525  1.312705  2.105817       0
# 4  -2.413939  1.007192 -1.291486 -2.234975       1
# ..       ...       ...       ...       ...     ...
# 95 -0.502235  1.065477 -0.949356 -1.007494       1
# 96 -1.543247 -0.241655  1.380136 -3.281536       1
# 97  0.417937  2.660665  1.264126  2.496129       0
# 98  1.648145  0.799271 -0.977379 -0.538647       0
# 99 -1.409011  0.082613 -1.014580 -0.706368       1
#
# [100 rows x 5 columns]
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df6=sample_columns(df,0.8)
print(df6)
# Out:
#         col4      Col1      col2      col5  Target
# 0   1.901801 -1.827113 -1.030160  0.216547       1
# 1   1.095708  0.036828 -0.258587  1.191991       0
# 2   2.776339  0.909340  2.582700  3.169328       0
# 3   1.565525  1.312705  0.563634  2.105817       0
# 4   1.007192 -1.291486 -1.924846 -2.234975       1
# ..       ...       ...       ...       ...     ...
# 95  1.065477 -0.949356 -0.360138 -1.007494       1
# 96 -0.241655  1.380136 -0.416913 -3.281536       1
# 97  2.660665  1.264126  2.917280  2.496129       0
# 98  0.799271 -0.977379  1.117682 -0.538647       0
# 99  0.082613 -1.014580 -0.461554 -0.706368       1
#
# [100 rows x 5 columns]
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
clf4=DecisionTreeClassifier()
clf5=DecisionTreeClassifier()
clf6=DecisionTreeClassifier()

# %%
clf4.fit(df4.iloc[:,0:4],df4.iloc[:,-1])
clf5.fit(df5.iloc[:,0:4],df5.iloc[:,-1])
clf6.fit(df6.iloc[:,0:4],df6.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
print(df4.columns)
# Out:
# Index(['col3', 'col4', 'Col1', 'col2', 'Target'], dtype='object')

# %%
plot_tree(clf4)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[0] <= 0.103\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.2222222222222222, 0.75, 'x[2] <= 0.568\ngini = 0.145\nsamples = 51\nvalue = [4, 47]'),
#  Text(0.3333333333333333, 0.8333333333333333, 'True  '),
#  Text(0.1111111111111111, 0.5833333333333334, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'x[0] <= -1.162\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4444444444444444, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.75, 'x[2] <= -1.33\ngini = 0.15\nsamples = 49\nvalue = [45.0, 4.0]'),
#  Text(0.5555555555555556, 0.8333333333333333, '  False'),
#  Text(0.5555555555555556, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
plot_tree(clf5)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[0] <= 0.103\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.2222222222222222, 0.75, 'x[3] <= 1.693\ngini = 0.145\nsamples = 51\nvalue = [4, 47]'),
#  Text(0.3333333333333333, 0.8333333333333333, 'True  '),
#  Text(0.1111111111111111, 0.5833333333333334, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.75, 'x[2] <= -1.33\ngini = 0.15\nsamples = 49\nvalue = [45.0, 4.0]'),
#  Text(0.5555555555555556, 0.8333333333333333, '  False'),
#  Text(0.5555555555555556, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7777777777777778, 0.5833333333333334, 'x[0] <= 0.739\ngini = 0.117\nsamples = 48\nvalue = [45, 3]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[1] <= -0.377\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
# ...

# %%
plot_tree(clf6)
# Out:
# [Text(0.39285714285714285, 0.9285714285714286, 'x[1] <= -0.206\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.14285714285714285, 0.7857142857142857, 'x[0] <= -0.603\ngini = 0.159\nsamples = 46\nvalue = [4, 42]'),
#  Text(0.26785714285714285, 0.8571428571428572, 'True  '),
#  Text(0.07142857142857142, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21428571428571427, 0.6428571428571429, 'x[3] <= 1.696\ngini = 0.087\nsamples = 44\nvalue = [2, 42]'),
#  Text(0.14285714285714285, 0.5, 'x[2] <= 0.981\ngini = 0.045\nsamples = 43\nvalue = [1, 42]'),
#  Text(0.07142857142857142, 0.35714285714285715, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(0.21428571428571427, 0.35714285714285715, 'x[0] <= 0.435\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.14285714285714285, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2857142857142857, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
clf4.predict(np.array([0.793532, -0.353361, -1.558092,  4.018724]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf5.predict(np.array([0.793532,-0.353361,-1.558092,4.018724]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf6.predict(np.array([0.793532,-0.353361,-1.558092 ,4.018724]).reshape(1,4))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df7 = combined_sampling(df,0.5,0.5)
# Out:
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Target']=df['Target']

# %%
df8 = combined_sampling(df,0.5,0.5)
# Out:
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Target']=df['Target']

# %%
df9 = combined_sampling(df,0.5,0.5)
# Out:
# <ipython-input-90-9b7658937e4d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Target']=df['Target']

# %%
print(df7.columns)
print(df8.columns)
print(df9.columns)
# Out:
# Index(['col2', 'col3', 'Target'], dtype='object')
# Index(['col4', 'col3', 'Target'], dtype='object')
# Index(['col4', 'col2', 'Target'], dtype='object')

# %%
df9
# Out:
#         col4      col2  Target
# 3   1.565525  0.563634       0
# 65  1.727568 -2.861086       1
# 84  2.014588 -2.814343       1
# 8   1.079890  0.624077       0
# 52  0.070894  1.605389       1
# 35 -0.070846  0.176496       1
# 69  1.383847  2.666984       0
# 89  0.588820 -1.452327       1
# 0   1.901801 -1.030160       1
# 45  1.478925  2.525874       0
# 60 -0.476899  0.671403       1
# 17  1.196211 -2.084159       1
# 58  1.274015 -1.801192       1
# 53 -0.742927 -1.922225       0
# 41  1.374800 -0.006221       1
# 39  1.578896 -0.843061       1
# 72  1.767348  1.761470       0
# 80  1.322675 -1.404560       1
# 63 -0.277297  0.729072       0
# 96 -0.241655 -0.416913       1
# 11  0.587863  0.996967       0
# 40  2.396921  3.899105       0
# 20 -1.199522 -0.956377       1
# 35 -0.070846  0.176496       1
# 35 -0.070846  0.176496       1
# 21  1.047253  2.398999       0
# 69  1.383847  2.666984       0
# 49  0.816100 -1.775238       1
# 8   1.079890  0.624077       0
# ...

# %%
clf7=DecisionTreeClassifier()
clf8=DecisionTreeClassifier()
clf9=DecisionTreeClassifier()

# %%
clf7.fit(df7.iloc[:,0:2],df7.iloc[:,-1])
clf8.fit(df8.iloc[:,0:2],df8.iloc[:,-1])
clf9.fit(df9.iloc[:,0:2],df9.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf7)
# Out:
# [Text(0.6666666666666666, 0.9, 'x[1] <= 0.264\ngini = 0.461\nsamples = 50\nvalue = [18, 32]'),
#  Text(0.5, 0.7, 'x[0] <= 2.066\ngini = 0.111\nsamples = 34\nvalue = [2, 32]'),
#  Text(0.5833333333333333, 0.8, 'True  '),
#  Text(0.3333333333333333, 0.5, 'x[1] <= 0.04\ngini = 0.059\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.16666666666666666, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.5, 0.3, 'x[1] <= 0.072\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.7, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.75, 0.8, '  False')]

# %%
plot_tree(clf8)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 0.24\ngini = 0.493\nsamples = 50\nvalue = [22.0, 28.0]'),
#  Text(0.25, 0.625, 'x[0] <= 2.257\ngini = 0.225\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.375, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.75, 0.625, 'x[1] <= 0.739\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[1] <= 0.723\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]')]

# %%
plot_tree(clf9)
# Out:
# [Text(0.5555555555555556, 0.9166666666666666, 'x[1] <= 0.316\ngini = 0.5\nsamples = 50\nvalue = [25, 25]'),
#  Text(0.3333333333333333, 0.75, 'x[0] <= -0.492\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.4444444444444444, 0.8333333333333333, 'True  '),
#  Text(0.2222222222222222, 0.5833333333333334, 'x[1] <= -1.302\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1111111111111111, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4444444444444444, 0.5833333333333334, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.7777777777777778, 0.75, 'x[0] <= 0.362\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.6666666666666667, 0.8333333333333333, '  False'),
#  Text(0.6666666666666666, 0.5833333333333334, 'x[1] <= 0.786\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
# ...

# %%
clf7.predict(np.array([1.727568,-2.861086]).reshape(1,2))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf8.predict(np.array([1.727568,	-2.861086]).reshape(1,2))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf9.predict(np.array([1.727568,	-2.861086]).reshape(1,2))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
